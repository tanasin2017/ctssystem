# %%
import pandas as pd
import numpy as np

# %%
data_destination_u = pd.read_excel('/Users/tanasinyatsungnoen/Desktop/CTS_Research/DataSet_Courses_Syllabus-cleansing_data2.xlsx', sheet_name='Destination_U')
data_destination_u
# Out:
#     No Course_Code                                   Course_Name Course_Group  \
# 0    1     MSC-101                      Introduction Programming         Core
# 1    2     MSC-102                             Introduction of C     Elective
# 2    3     INT-102                  Computer Programming Lab (C)         Core
# 3    4     INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 4    5     INT-201  Computer Network and Communication Systems 1         Core
# 5    6     INT-301                  Software and Database System     Elective
# 6    7     INT-303                          Software Engineering     Elective
# 7    8     MSC-126        Mathematics for Information Technology         Core
# 8    9     MSC-127      Mathematics for Information Technology 2         Core
# 9   10     MSC-201                       Mathematical Statistics     Elective
# 10  11     ITE-418                  Data Structure and Algorithm     Elective
#
# ...

# %%
data_previous_u = pd.read_excel('/Users/tanasinyatsungnoen/Desktop/CTS_Research/DataSet_Courses_Syllabus-cleansing_data2.xlsx', sheet_name='Previous_U')
data_previous_u
# Out:
#     No Course_Code                   Course_Name Course_Group  Credit  \
# 0    1     ABC-123                 C Programming         Core       3
# 1    2     ABC-124             C Programming Lab         Core       1
# 2    3     ABC-125               JAVA Programing         Core       3
# 3    4     ABC-126           JAVA Programing Lab         Core       1
# 4    5     ABC-127            Network Technology         Core       1
# 5    6     ABC-128  Database Analysis and Design     Elective       3
# 6    7     ABC-129          Software engineering     Elective       3
# 7    8     ABC-130                 Mathematics 1         Core       3
# 8    9     ABC-131                 Mathematics 2         Core       3
# 9   10     ABC-132                Data Structure     Elective       3
# 10  11     ABC-133     Introducion to Algorithms     Elective       3
#
#    Course_Type                   Content_1                Content_2  \
# ...

# %%
type(data_previous_u)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.__version__
# Out:
# '0.23.4'

# %%
#data_previous_u.loc['ABC-123':'ABC-133','Content_1':'Content_10']
# Out:
#                               Content_1                Content_2  \
# Course_Code
# ABC-123                         Pointer                 Loop (C)
# ABC-124                        Operator                 File (C)
# ABC-125                 Variable (JAVA)             Array (JAVA)
# ABC-126      Control Statement Decision                    Class
# ABC-127               Package switching      Network Application
# ABC-128                             UML     Requirement analysis
# ABC-129         Centralization Database     Distributed Database
# ABC-130                           Limit  Surface area and Volume
# ABC-131                Linear Equations   Tangent line equations
# ABC-132                           Graph                  Hashing
# ABC-133                         Sorting      Binary Search Tree
#
#                           Content_3                     Content_4  \
# Course_Code
# ABC-123               Condition (C)              Input and Output
# ...

# %%
data_previous_u
# Out:
#     No Course_Code                   Course_Name Course_Group  Credit  \
# 0    1     ABC-123                 C Programming         Core       3
# 1    2     ABC-124             C Programming Lab         Core       1
# 2    3     ABC-125               JAVA Programing         Core       3
# 3    4     ABC-126           JAVA Programing Lab         Core       1
# 4    5     ABC-127            Network Technology         Core       1
# 5    6     ABC-128  Database Analysis and Design     Elective       3
# 6    7     ABC-129          Software engineering     Elective       3
# 7    8     ABC-130                 Mathematics 1         Core       3
# 8    9     ABC-131                 Mathematics 2         Core       3
# 9   10     ABC-132                Data Structure     Elective       3
# 10  11     ABC-133     Introducion to Algorithms     Elective       3
#
#    Course_Type                   Content_1                Content_2  \
# ...

# %%
data_destination_u
# Out:
#     No Course_Code                                   Course_Name Course_Group  \
# 0    1     MSC-101                      Introduction Programming         Core
# 1    2     MSC-102                             Introduction of C     Elective
# 2    3     INT-102                  Computer Programming Lab (C)         Core
# 3    4     INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 4    5     INT-201  Computer Network and Communication Systems 1         Core
# 5    6     INT-301                  Software and Database System     Elective
# 6    7     INT-303                          Software Engineering     Elective
# 7    8     MSC-126        Mathematics for Information Technology         Core
# 8    9     MSC-127      Mathematics for Information Technology 2         Core
# 9   10     MSC-201                       Mathematical Statistics     Elective
# 10  11     ITE-418                  Data Structure and Algorithm     Elective
#
# ...

# %% [markdown]
# https://www.shanelynn.ie/using-pandas-dataframe-creating-editing-viewing-data-in-python/

# %%
#all_data = data_previous_u == data_destination_u.all()[0]

# %%
data_previous_u.iloc[:,:]
# Out:
#     No Course_Code                   Course_Name Course_Group  Credit  \
# 0    1     ABC-123                 C Programming         Core       3
# 1    2     ABC-124             C Programming Lab         Core       1
# 2    3     ABC-125               JAVA Programing         Core       3
# 3    4     ABC-126           JAVA Programing Lab         Core       1
# 4    5     ABC-127            Network Technology         Core       1
# 5    6     ABC-128  Database Analysis and Design     Elective       3
# 6    7     ABC-129          Software engineering     Elective       3
# 7    8     ABC-130                 Mathematics 1         Core       3
# 8    9     ABC-131                 Mathematics 2         Core       3
# 9   10     ABC-132                Data Structure     Elective       3
# 10  11     ABC-133     Introducion to Algorithms     Elective       3
#
#    Course_Type                   Content_1                Content_2  \
# ...

# %%
data_previous_u
# Out:
#     No Course_Code                   Course_Name Course_Group  Credit  \
# 0    1     ABC-123                 C Programming         Core       3
# 1    2     ABC-124             C Programming Lab         Core       1
# 2    3     ABC-125               JAVA Programing         Core       3
# 3    4     ABC-126           JAVA Programing Lab         Core       1
# 4    5     ABC-127            Network Technology         Core       1
# 5    6     ABC-128  Database Analysis and Design     Elective       3
# 6    7     ABC-129          Software engineering     Elective       3
# 7    8     ABC-130                 Mathematics 1         Core       3
# 8    9     ABC-131                 Mathematics 2         Core       3
# 9   10     ABC-132                Data Structure     Elective       3
# 10  11     ABC-133     Introducion to Algorithms     Elective       3
#
#    Course_Type                   Content_1                Content_2  \
# ...

# %%
#for i in data_previous_u.iloc[:5,:]:
for i in data_previous_u.iterrows(): #For loop in DataFrame
    print(i)
# Out:
# (0, No                             1
# Course_Code              ABC-123
# Course_Name        C Programming
# Course_Group                Core
# Credit                         3
# Course_Type              Lecture
# Content_1                Pointer
# Content_2               Loop (C)
# Content_3          Condition (C)
# Content_4       Input and Output
# Content_5             Flow chart
# Content_6           Variable (C)
# Content_7             Expression
# Content_8               Operator
# Content_9              Array (C)
# Content_10              File (C)
# Name: 0, dtype: object)
# (1, No                              2
# Course_Code               ABC-124
# Course_Name     C Programming Lab
# Course_Group                 Core
# Credit                          1
# Course_Type                   Lab
# Content_1                Operator
# Content_2                File (C)
# Content_3              Expression
# Content_4                 Pointer
# Content_5            Function (C)
# ...

# %% [markdown]
# https://stackoverflow.com/questions/16476924/how-to-iterate-over-rows-in-a-dataframe-in-pandas

# %%
for j in data_destination_u.iterrows(): #For loop in DataFrame of destination University
    print(j)
# Out:
# (0, No                                     1
# Course_Code                      MSC-101
# Course_Name     Introduction Programming
# Course_Group                        Core
# Credit                                 3
# Course_Type                      Lecture
# Content_1                        Pointer
# Content_2                  Condition (C)
# Content_3                     Flow chart
# Content_4                   Variable (C)
# Content_5                       Operator
# Content_6                   Array (JAVA)
# Content_7                    File (JAVA)
# Content_8                            GUI
# Content_9                Abstract Object
# Content_10                   Loop (JAVA)
# Name: 0, dtype: object)
# (1, No                              2
# Course_Code               MSC-102
# Course_Name     Introduction of C
# Course_Group             Elective
# Credit                          4
# Course_Type               Lecture
# Content_1                 Pointer
# ...

# %%
for y in data_previous_u.iterrows(): #For loop in DataFrame
    for x in data_destination_u.iterrows(): #For loop in DataFrame
    if x   
    print(x,y)
# Out:
# (0, No                                     1
# Course_Code                      MSC-101
# Course_Name     Introduction Programming
# Course_Group                        Core
# Credit                                 3
# Course_Type                      Lecture
# Content_1                        Pointer
# Content_2                  Condition (C)
# Content_3                     Flow chart
# Content_4                   Variable (C)
# Content_5                       Operator
# Content_6                   Array (JAVA)
# Content_7                    File (JAVA)
# Content_8                            GUI
# Content_9                Abstract Object
# Content_10                   Loop (JAVA)
# Name: 0, dtype: object) (0, No                             1
# Course_Code              ABC-123
# Course_Name        C Programming
# Course_Group                Core
# Credit                         3
# Course_Type              Lecture
# Content_1                Pointer
# Content_2               Loop (C)
# ...
