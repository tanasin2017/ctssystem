# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('/Users/tanasinyatsungnoen/Desktop/CTS_Research/DataSet_Courses_Syllabus-cleansing_data2.xlsx')

# %%
data
# Out:
#    Course Code                                   Course Name Course group  \
# 0      MSC-101                      Introduction Programming         Core
# 1      INT-102                  Computer Programming Lab (C)         Core
# 2      INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 3      INT-201  Computer Network and Communication Systems 1         Core
# 4      INT-301                  Software and Database System     Elective
# 5      INT-303                          Software Engineering     Elective
# 6      MSC-126        Mathematics for Information Technology         Core
# 7      MSC-127      Mathematics for Information Technology 2         Core
# 8      MSC-201                       Mathematical Statistics     Elective
# 9      ITE-418                  Data Structure and Algorithm     Elective
# 10     ABC-123                                 C Programming         Core
# 11     ABC-124                             C Programming Lab         Core
# ...

# %%
data
# Out:
#    Course Code                                   Course Name Course group  \
# 0      MSC-101                      Introduction Programming         Core
# 1      INT-102                  Computer Programming Lab (C)         Core
# 2      INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 3      INT-201  Computer Network and Communication Systems 1         Core
# 4      INT-301                  Software and Database System     Elective
# 5      INT-303                          Software Engineering     Elective
# 6      MSC-126        Mathematics for Information Technology         Core
# 7      MSC-127      Mathematics for Information Technology 2         Core
# 8      MSC-201                       Mathematical Statistics     Elective
# 9      ITE-418                  Data Structure and Algorithm     Elective
# 10     ABC-123                                 C Programming         Core
# 11     ABC-124                             C Programming Lab         Core
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#    Course Code                                   Course Name Course group  \
# 0      MSC-101                      Introduction Programming         Core
# 1      INT-102                  Computer Programming Lab (C)         Core
# 2      INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 3      INT-201  Computer Network and Communication Systems 1         Core
# 4      INT-301                  Software and Database System     Elective
# 5      INT-303                          Software Engineering     Elective
# 6      MSC-126        Mathematics for Information Technology         Core
# 7      MSC-127      Mathematics for Information Technology 2         Core
# 8      MSC-201                       Mathematical Statistics     Elective
# 9      ITE-418                  Data Structure and Algorithm     Elective
# 10     ABC-123                                 C Programming         Core
# 11     ABC-124                             C Programming Lab         Core
# ...

# %%
data[1:11].iloc[:,5:15]
# Out:
#                  Content 1                   Content 2  \
# 1             Variable (C)                    Loop (C)
# 2                    Class  Control Statement Decision
# 3           Physical Media                    Protocol
# 4      Database Management        Distributed Database
# 5                      UML           Coding techniques
# 6                    Limit            Linear Equations
# 7                 Counting           Set Decomposition
# 8   Descriptive statistics          Probability theory
# 9                Recursion                       Queue
# 10                 Pointer                    Loop (C)
#
#                        Content 3                    Content 4  \
# 1                      Array (C)                Condition (C)
# 2   Control Statement Repetition              Instance Method
# 3                Access Network             Package switching
# 4        Centralization Database         Requirement analysis
# ...

# %%
destination_u = data[1:11].iloc[:,5:15]

# %%
destination_u
# Out:
#                  Content 1                   Content 2  \
# 1             Variable (C)                    Loop (C)
# 2                    Class  Control Statement Decision
# 3           Physical Media                    Protocol
# 4      Database Management        Distributed Database
# 5                      UML           Coding techniques
# 6                    Limit            Linear Equations
# 7                 Counting           Set Decomposition
# 8   Descriptive statistics          Probability theory
# 9                Recursion                       Queue
# 10                 Pointer                    Loop (C)
#
#                        Content 3                    Content 4  \
# 1                      Array (C)                Condition (C)
# 2   Control Statement Repetition              Instance Method
# 3                Access Network             Package switching
# 4        Centralization Database         Requirement analysis
# ...

# %%
data[10:22].iloc[:,5:15]
# Out:
#   File "<ipython-input-24-73126d06859c>", line 1
#     data[[10:22].iloc[:,5:15]]
#             ^
# SyntaxError: invalid syntax

# %%
previous_u = data[10:22].iloc[:,5:15]

# %%
type(previous_u)
# Out:
# pandas.core.frame.DataFrame

# %%
print(previous_u[1:1])
# Out:
# Empty DataFrame
# Columns: [Content 1, Content 2, Content 3, Content 4, Content 5, Content 6, Content 7, Content 8, Content 9, Content 10]
# Index: []
