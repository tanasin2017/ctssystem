# %%
import pandas as pd
dataset = pd.read_excel('/Users/tanasinyatsungnoen/Desktop/CTS_Research/DataSet_Courses_Syllabus-combinedata.xlsx')

# %%
dataset
# Out:
#     No  Course Code                                   Course Name  \
# 0    1      MSC-101                      Introduction Programming
# 1    2      INT-102                  Computer Programming Lab (C)
# 2    3      INT-104        Object-Oriented Programming Lab (JAVA)
# 3    4      INT-201  Computer Network and Communication Systems 1
# 4    5      INT-301                  Software and Database System
# 5    6      INT-303                          Software Engineering
# 6    7      MSC-126        Mathematics for Information Technology
# 7    8      MSC-127      Mathematics for Information Technology 2
# 8    9      MSC-201                       Mathematical Statistics
# 9   10      ITE-418                  Data Structure and Algorithm
# 10  No  Course Code                                   Course Name
# 11   1      ABC-123                                 C Programming
# 12   2      ABC-124                             C Programming Lab
# ...

# %%
dataset.head()
# Out:
#   No Course Code                                   Course Name Course group  \
# 0  1     MSC-101                      Introduction Programming         Core
# 1  2     INT-102                  Computer Programming Lab (C)         Core
# 2  3     INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 3  4     INT-201  Computer Network and Communication Systems 1         Core
# 4  5     INT-301                  Software and Database System     Elective
#
#   Credit Course type            Content 1                   Content 2  \
# 0      3     Lecture              Pointer               Condition (C)
# 1      1         Lab         Variable (C)                    Loop (C)
# 2      1         Lab                Class  Control Statement Decision
# 3      1     Lecture       Physical Media                    Protocol
# 4      3     Lecture  Database Management        Distributed Database
#
#                       Content 3             Content 4            Content 5  \
# ...

# %%
dataset.columns
# Out:
# Index(['No', 'Course Code', 'Course Name', 'Course group', 'Credit',
#        'Course type', 'Content 1', 'Content 2', 'Content 3', 'Content 4',
#        'Content 5', 'Content 6', 'Content 7', 'Content 8', 'Content 9',
#        'Content 10'],
#       dtype='object')

# %%
dataset['Course Name']
# Out:
# 0                         Introduction Programming
# 1                     Computer Programming Lab (C)
# 2           Object-Oriented Programming Lab (JAVA)
# 3     Computer Network and Communication Systems 1
# 4                     Software and Database System
# 5                             Software Engineering
# 6           Mathematics for Information Technology
# 7         Mathematics for Information Technology 2
# 8                          Mathematical Statistics
# 9                     Data Structure and Algorithm
# 10                                     Course Name
# 11                                   C Programming
# 12                               C Programming Lab
# 13                                 JAVA Programing
# 14                             JAVA Programing Lab
# 15                              Network Technology
# 16                    Database Analysis and Design
# 17                            Software engineering
# ...

# %%
dataset[['Course Name']]
# Out:
#                                      Course Name
# 0                       Introduction Programming
# 1                   Computer Programming Lab (C)
# 2         Object-Oriented Programming Lab (JAVA)
# 3   Computer Network and Communication Systems 1
# 4                   Software and Database System
# 5                           Software Engineering
# 6         Mathematics for Information Technology
# 7       Mathematics for Information Technology 2
# 8                        Mathematical Statistics
# 9                   Data Structure and Algorithm
# 10                                   Course Name
# 11                                 C Programming
# 12                             C Programming Lab
# 13                               JAVA Programing
# 14                           JAVA Programing Lab
# 15                            Network Technology
# 16                  Database Analysis and Design
# 17                          Software engineering
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset
# Out:
#     No  Course Code                                   Course Name  \
# 0    1      MSC-101                      Introduction Programming
# 1    2      INT-102                  Computer Programming Lab (C)
# 2    3      INT-104        Object-Oriented Programming Lab (JAVA)
# 3    4      INT-201  Computer Network and Communication Systems 1
# 4    5      INT-301                  Software and Database System
# 5    6      INT-303                          Software Engineering
# 6    7      MSC-126        Mathematics for Information Technology
# 7    8      MSC-127      Mathematics for Information Technology 2
# 8    9      MSC-201                       Mathematical Statistics
# 9   10      ITE-418                  Data Structure and Algorithm
# 10  No  Course Code                                   Course Name
# 11   1      ABC-123                                 C Programming
# 12   2      ABC-124                             C Programming Lab
# ...

# %%
dataset
# Out:
#     No  Course Code                                   Course Name  \
# 0    1      MSC-101                      Introduction Programming
# 1    2      INT-102                  Computer Programming Lab (C)
# 2    3      INT-104        Object-Oriented Programming Lab (JAVA)
# 3    4      INT-201  Computer Network and Communication Systems 1
# 4    5      INT-301                  Software and Database System
# 5    6      INT-303                          Software Engineering
# 6    7      MSC-126        Mathematics for Information Technology
# 7    8      MSC-127      Mathematics for Information Technology 2
# 8    9      MSC-201                       Mathematical Statistics
# 9   10      ITE-418                  Data Structure and Algorithm
# 10  No  Course Code                                   Course Name
# 11   1      ABC-123                                 C Programming
# 12   2      ABC-124                             C Programming Lab
# ...

# %%
dataset.drop([10], axis=0)
# Out:
#     No Course Code                                   Course Name Course group  \
# 0    1     MSC-101                      Introduction Programming         Core
# 1    2     INT-102                  Computer Programming Lab (C)         Core
# 2    3     INT-104        Object-Oriented Programming Lab (JAVA)         Core
# 3    4     INT-201  Computer Network and Communication Systems 1         Core
# 4    5     INT-301                  Software and Database System     Elective
# 5    6     INT-303                          Software Engineering     Elective
# 6    7     MSC-126        Mathematics for Information Technology         Core
# 7    8     MSC-127      Mathematics for Information Technology 2         Core
# 8    9     MSC-201                       Mathematical Statistics     Elective
# 9   10     ITE-418                  Data Structure and Algorithm     Elective
# 11   1     ABC-123                                 C Programming         Core
# ...

# %%
dataset
# Out:
#     No  Course Code                                   Course Name  \
# 0    1      MSC-101                      Introduction Programming
# 1    2      INT-102                  Computer Programming Lab (C)
# 2    3      INT-104        Object-Oriented Programming Lab (JAVA)
# 3    4      INT-201  Computer Network and Communication Systems 1
# 4    5      INT-301                  Software and Database System
# 5    6      INT-303                          Software Engineering
# 6    7      MSC-126        Mathematics for Information Technology
# 7    8      MSC-127      Mathematics for Information Technology 2
# 8    9      MSC-201                       Mathematical Statistics
# 9   10      ITE-418                  Data Structure and Algorithm
# 10  No  Course Code                                   Course Name
# 11   1      ABC-123                                 C Programming
# 12   2      ABC-124                             C Programming Lab
# ...
